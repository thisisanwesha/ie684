# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('haberman.data',sep=',',header=None)

# %%
df.columns=['Age of patient','Year of operation','No of positive axillary nodes detected','Survival Status']

# %%
df
# Out:
#      Age of patient  Year of operation  \
# 0                30                 64
# 1                30                 62
# 2                30                 65
# 3                31                 59
# 4                31                 65
# ..              ...                ...
# 301              75                 62
# 302              76                 67
# 303              77                 65
# 304              78                 65
# 305              83                 58
#
#      No of positive axillary nodes detected  Survival Status
# 0                                         1                1
# 1                                         3                1
# 2                                         0                1
# 3                                         2                1
# 4                                         4                1
# ..                                      ...              ...
# 301                                       1                1
# 302                                       0                1
# 303                                       3                1
# 304                                       1                2
# 305                                       2                2
#
# [306 rows x 4 columns]

# %%
y = df['Survival Status']
X = df.drop('Survival Status', axis = 1)

# %%
 K = np.array(list(range(1,6)))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100)

test_L1 = []
test_L2 = []
print("K\t L1 accuracy\t   \t L2 accuracy")
for i in K:
  clf = KNeighborsClassifier(n_neighbors = i, metric='manhattan')
  clf.fit(X_train, y_train)
  test_score_L1 = clf.score(X_test, y_test)
    
  clf = KNeighborsClassifier(n_neighbors = i, metric='euclidean')
  clf.fit(X_train, y_train)
  test_score_L2 = clf.score(X_test, y_test)
    
  test_L1.append(test_score_L1)
  test_L2.append(test_score_L2)
  print(i,"\t",test_score_L1,"\t",test_score_L2)
# Out:
# K	 L1 accuracy	   	 L2 accuracy
# 1 	 0.7096774193548387 	 0.7096774193548387
# 2 	 0.7580645161290323 	 0.7741935483870968
# 3 	 0.7258064516129032 	 0.7419354838709677
# 4 	 0.7419354838709677 	 0.7419354838709677
# 5 	 0.7258064516129032 	 0.7419354838709677

# %%
plt.plot(K,test_L1, color='b',marker='*', label='L1')
plt.plot(K,test_L2, color='r', marker='o', label='L2')
plt.xlabel('k (Number of clusters)')
plt.ylabel('Test Accuracy')
plt.title("Graph between k and test accuracy for Train-Test Split 80:20")
plt.legend()
plt.show()

# %%
plt.bar(K-0.1,test_L1, color='b', width=0.25, label='L1')
plt.bar(K+0.1,test_L2, color='r', width=0.25, label='L2')
plt.xlabel('k (Number of clusters)')
plt.ylabel('Test Accuracy')
plt.title("Graph between k and test accuracy for Train-Test Split 80:20")
plt.legend()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 100)

test_L1 = []
test_L2 = []
print("K\t L1 accuracy\t   \t L2 accuracy")
for i in K:
  clf = KNeighborsClassifier(n_neighbors = i, metric='manhattan')
  clf.fit(X_train, y_train)
  test_score_L1 = clf.score(X_test, y_test)
    
  clf = KNeighborsClassifier(n_neighbors = i, metric='euclidean')
  clf.fit(X_train, y_train)
  test_score_L2 = clf.score(X_test, y_test)
    
  test_L1.append(test_score_L1)
  test_L2.append(test_score_L2)
  print(i,"\t",test_score_L1,"\t",test_score_L2)
# Out:
# K	 L1 accuracy	   	 L2 accuracy
# 1 	 0.7317073170731707 	 0.7479674796747967
# 2 	 0.7642276422764228 	 0.7804878048780488
# 3 	 0.7479674796747967 	 0.7479674796747967
# 4 	 0.7723577235772358 	 0.7804878048780488
# 5 	 0.7642276422764228 	 0.7967479674796748

# %%
plt.plot(K,test_L1, color='b',marker='*', label='L1')
plt.plot(K,test_L2, color='r', marker='o', label='L2')
plt.xlabel('k (Number of clusters)')
plt.ylabel('Test Accuracy')
plt.title("Graph between k and test accuracy for Train-Test Split 60:40")
plt.legend()
plt.show()

# %%
plt.bar(K-0.1,test_L1, color='b', width=0.25, label='L1')
plt.bar(K+0.1,test_L2, color='r', width=0.25, label='L2')
plt.xlabel('k (Number of clusters)')
plt.ylabel('Test Accuracy')
plt.title("Graph between k and test accuracy for Train-Test Split 60:40")
plt.legend()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)

test_L1 = []
test_L2 = []
print("K\t L1 accuracy\t   \t L2 accuracy")
for i in K:
  clf = KNeighborsClassifier(n_neighbors = i, metric='manhattan')
  clf.fit(X_train, y_train)
  test_score_L1 = clf.score(X_test, y_test)
    
  clf = KNeighborsClassifier(n_neighbors = i, metric='euclidean')
  clf.fit(X_train, y_train)
  test_score_L2 = clf.score(X_test, y_test)
    
  test_L1.append(test_score_L1)
  test_L2.append(test_score_L2)
  print(i,"\t",test_score_L1,"\t",test_score_L2)
# Out:
# K	 L1 accuracy	   	 L2 accuracy
# 1 	 0.7282608695652174 	 0.75
# 2 	 0.7608695652173914 	 0.7717391304347826
# 3 	 0.7391304347826086 	 0.7391304347826086
# 4 	 0.7608695652173914 	 0.7608695652173914
# 5 	 0.7282608695652174 	 0.7608695652173914

# %%
plt.plot(K,test_L1, color='b',marker='*', label='L1')
plt.plot(K,test_L2, color='r', marker='o', label='L2')
plt.xlabel('k (Number of clusters)')
plt.ylabel('Test Accuracy')
plt.title("Graph between k and test accuracy for Train-Test Split 70:30")
plt.legend()
plt.show()

# %%
plt.bar(K-0.1,test_L1, color='b', width=0.25, label='L1')
plt.bar(K+0.1,test_L2, color='r', width=0.25, label='L2')
plt.xlabel('k (Number of clusters)')
plt.ylabel('Test Accuracy')
plt.title("Graph between k and test accuracy for Train-Test Split 70:30")
plt.legend()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 100)

test_L1 = []
test_L2 = []
print("K\t L1 accuracy\t   \t L2 accuracy")
for i in K:
  clf = KNeighborsClassifier(n_neighbors = i, metric='manhattan')
  clf.fit(X_train, y_train)
  test_score_L1 = clf.score(X_test, y_test)
    
  clf = KNeighborsClassifier(n_neighbors = i, metric='euclidean')
  clf.fit(X_train, y_train)
  test_score_L2 = clf.score(X_test, y_test)
    
  test_L1.append(test_score_L1)
  test_L2.append(test_score_L2)
  print(i,"\t",test_score_L1,"\t",test_score_L2)
# Out:
# K	 L1 accuracy	   	 L2 accuracy
# 1 	 0.7096774193548387 	 0.7419354838709677
# 2 	 0.7741935483870968 	 0.8064516129032258
# 3 	 0.7096774193548387 	 0.7741935483870968
# 4 	 0.7741935483870968 	 0.7741935483870968
# 5 	 0.7419354838709677 	 0.7419354838709677

# %%
plt.plot(K,test_L1, color='b',marker='*', label='L1')
plt.plot(K,test_L2, color='r', marker='o', label='L2')
plt.xlabel('k (Number of clusters)')
plt.ylabel('Test Accuracy')
plt.title("Graph between k and test accuracy for Train-Test Split 90:10")
plt.legend()
plt.show()

# %%
plt.bar(K-0.1,test_L1, color='b', width=0.25, label='L1')
plt.bar(K+0.1,test_L2, color='r', width=0.25, label='L2')
plt.xlabel('k (Number of clusters)')
plt.ylabel('Test Accuracy')
plt.title("Graph between k and test accuracy for Train-Test Split 90:10")
plt.legend()
plt.show()
