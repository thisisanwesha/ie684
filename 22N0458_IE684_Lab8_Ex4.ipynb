# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.decomposition import PCA
from mpl_toolkits import mplot3d
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.metrics import silhouette_score
import scipy.cluster.hierarchy as shc
from scipy.cluster.hierarchy import dendrogram

# %%
df=pd.read_csv('hierarchical.csv',header=None)

# %%
df.columns=df.iloc[0]
df=df[1:]

# %%
df
# Out:
# 0           x         y         z
# 1    153.5885   33.0716  46.68676
# 2    36.02489   41.3983  127.1009
# 3    4.513605  42.45976  132.8075
# 4    146.0287  37.32747  57.05478
# 5    44.39309  43.69293  118.4999
# ..        ...       ...       ...
# 196  13.20202  69.17549  133.6188
# 197  31.59107  35.88656  64.00113
# 198  151.9508  37.89974  64.29086
# 199  84.04791    52.828  53.47007
# 200  128.8612  51.22401  57.76302
#
# [200 rows x 3 columns]

# %%
sc = StandardScaler()
X = sc.fit_transform(df)
#X = normalize(X)

# %%
#pca = PCA(n_components = 2)
#X = pca.fit_transform(X)

# %%
X
# Out:
# array([[ 1.49955224e+00, -4.37622213e-01, -1.15972561e+00],
#        [-6.00506399e-01, -5.22822671e-02,  1.48934062e+00],
#        [-1.16339781e+00, -3.16041346e-03,  1.67733195e+00],
#        [ 1.36451025e+00, -2.40670633e-01, -8.18174089e-01],
#        [-4.51023828e-01,  5.39077721e-02,  1.20599967e+00],
#        [ 6.39826493e-01,  8.50717402e-01, -6.55895593e-01],
#        [ 1.07987852e+00, -7.42074876e-01, -1.10660305e+00],
#        [-1.02493261e+00,  1.05493133e+00,  1.38020774e+00],
#        [-9.02273200e-01,  8.45625373e-02,  8.75076156e-01],
#        [ 3.88960792e-01,  1.58210203e+00,  3.74426768e-01],
#        [ 8.96838196e-01,  8.37374172e-01,  4.33005640e-01],
#        [ 4.19758503e-01,  1.48779285e+00, -2.89394193e-01],
#        [ 6.91656478e-01, -4.63772313e-01, -5.98741827e-01],
#        [ 8.32554010e-01,  5.50213145e-01, -9.36244347e-01],
#        [ 8.06888209e-01,  1.36361562e+00, -2.47327896e-01],
#        [ 4.14691794e-01, -3.77094311e-01, -3.70015086e-01],
# ...

# %% [markdown]
# Ward

# %%
plt.title('Dendrogram using ward method')
Dendrogram = shc.dendrogram((shc.linkage(X, method ='ward')))

# %%
k = [2,3,4,5,6]

silhouette_scores = []
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 2, linkage='ward').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 3, linkage='ward').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 4, linkage='ward').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 5, linkage='ward').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 6, linkage='ward').fit_predict(X)))


plt.bar(k, silhouette_scores)
plt.xlabel('Number of clusters')
plt.ylabel('Silhoutte scores')
plt.title('Linkage ward')
plt.show()

# %%
ax = plt.axes(projection ="3d")
 
ax.scatter3D(X[:,0], X[:,1], X[:,2], c=AgglomerativeClustering(n_clusters = 3, linkage='ward').fit_predict(X), cmap='rainbow')
plt.title("K=3 using ward linkage")

plt.show()

# %% [markdown]
# Single

# %%
plt.title('Dendrogram using single method')
Dendrogram = shc.dendrogram((shc.linkage(X, method ='single')))

# %%
k = [2,3,4,5,6]

silhouette_scores = []
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 2, linkage='single').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 3, linkage='single').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 4, linkage='single').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 5, linkage='single').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 6, linkage='single').fit_predict(X)))


plt.bar(k, silhouette_scores)
plt.xlabel('Number of clusters')
plt.ylabel('Silhoutte scores')
plt.title('Linkage single')
plt.show()

# %%
ax = plt.axes(projection ="3d")
 
ax.scatter3D(X[:,0], X[:,1], X[:,2], c=AgglomerativeClustering(n_clusters = 3, linkage='single').fit_predict(X), cmap='rainbow')
plt.title("K=3 using single linkage")

plt.show()

# %% [markdown]
# Average

# %%
plt.title('Dendrogram using average method')
Dendrogram = shc.dendrogram((shc.linkage(X, method ='average')))

# %%
k = [2,3,4,5,6]

silhouette_scores = []
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 2, linkage='average').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 3, linkage='average').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 4, linkage='average').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 5, linkage='average').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 6, linkage='average').fit_predict(X)))


plt.bar(k, silhouette_scores)
plt.xlabel('Number of clusters')
plt.ylabel('Silhoutte scores')
plt.title('Linkage average')
plt.show()

# %%
ax = plt.axes(projection ="3d")
 
ax.scatter3D(X[:,0], X[:,1], X[:,2], c=AgglomerativeClustering(n_clusters = 3, linkage='average').fit_predict(X), cmap='rainbow')
plt.title("K=3 using average linkage")

plt.show()

# %% [markdown]
# Complete

# %%
plt.title('Dendrogram using complete method')
Dendrogram = shc.dendrogram((shc.linkage(X, method ='complete')))

# %%
k = [2,3,4,5,6]

silhouette_scores = []
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 2, linkage='complete').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 3, linkage='complete').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 4, linkage='complete').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 5, linkage='complete').fit_predict(X)))
silhouette_scores.append(silhouette_score(X, AgglomerativeClustering(n_clusters = 6, linkage='complete').fit_predict(X)))


plt.bar(k, silhouette_scores)
plt.xlabel('Number of clusters')
plt.ylabel('Silhoutte scores')
plt.title('Linkage complete')
plt.show()

# %%
ax = plt.axes(projection ="3d")
 
ax.scatter3D(X[:,0], X[:,1], X[:,2], c=AgglomerativeClustering(n_clusters = 4, linkage='complete').fit_predict(X), cmap='rainbow')
plt.title("K=4 using complete linkage")

plt.show()

# %% [markdown]
# Conclusion:
# According to the algorithm for bottom up clustering, it seems appropriate to use single method. From the dendrogram, it seems that optimal number of clusters=2. But from silhoutte values, we get optimal number of clusters=3 (plot above).

# %%
ax = plt.axes(projection ="3d")
 
ax.scatter3D(X[:,0], X[:,1], X[:,2], c=AgglomerativeClustering(n_clusters = 2, linkage='single').fit_predict(X), cmap='rainbow')
plt.title("K=2 using single linkage")

plt.show()
